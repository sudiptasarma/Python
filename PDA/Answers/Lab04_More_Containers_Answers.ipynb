# %% [markdown]
# ## Exercises Lab04 More Containers

# %%
# 1. Here are some interesting data.  Get them into a DataFrame.  Pick the most meaningful index and column. 

data = [['State', 'Capital', 'Largest City', 'Bird', 'Flower'] ,
        ['Alabama', 'Montgomery', 'Birmingham', 'Yellowhammer', 'Camellia'],
        ['Alaska', 'Juneau', 'Anchorage', 'Willow Ptarmigan', 'Forget-me-not'],
        ['Arizona', 'Phoenix', 'Phoenix', 'Cactus Wren', 'Saguaro Cactus Blossom'],
        ['Arkansas', 'Little Rock', 'Little Rock', 'Mockingbird', 'Apple Blossom'],
        ['California', 'Sacramento', 'Los Angeles', 'California Valley Quail', 'Golden Poppy'],
        ['Colorado', 'Denver', 'Denver', 'Lark Bunting', 'Columbine'],
        ['Connecticut', 'Hartford', 'Bridgeport', 'American Robin', 'Mountain Laurel'],
        ['Delaware', 'Dover', 'Wilmington', 'Blue Hen Chicken', 'Peach Blossom'],
        ['Florida', 'Tallahassee', 'Jacksonville', 'Mockingbird', 'Orange Blossom'],
        ['Georgia', 'Atlanta', 'Atlanta', 'Brown Thrasher', 'Cherokee Rose'],
        ['Hawaii', 'Honolulu', 'Honolulu', 'Nene (Hawaiian Goose)', 'Hibiscus'],
        ['Idaho', 'Boise', 'Boise', 'Mountain Bluebird', 'Syringa'],
        ['Illinois', 'Springfield', 'Chicago', 'Cardinal', 'Native violet'],
        ['Indiana', 'Indianapolis', 'Indianapolis', 'Cardinal', 'Peony'],
        ['Iowa', 'Des Moines', 'Des Moines', 'Eastern Goldfinch', 'Wild Rose'],
        ['Kansas', 'Topeka', 'Wichita', 'Western Meadowlark', 'Native Sunflower'],
        ['Kentucky', 'Frankfort', 'Louisville', 'Kentucky Cardinal', 'Goldenrod'],
        ['Louisiana', 'Baton Rouge', 'New Orleans', 'Pelican', 'Magnolia'],
        ['Maine', 'Augusta', 'Portland', 'Chickadee', 'White Pine Cone and Tassel'],
        ['Maryland', 'Annapolis', 'Baltimore', 'Baltimore Oriole', 'Black-Eyed Susan'],
        ['Massachusetts', 'Boston', 'Boston', 'Chickadee', 'Mayflower'],
        ['Michigan', 'Lansing', 'Detroit', 'Robin', 'Apple Blossom'],
        ['Minnesota', 'St. Paul', 'Minneapolis', 'Common Loon', "Pink and White Lady's Slipper"],
        ['Mississippi', 'Jackson', 'Jackson', 'Mockingbird', 'Magnolia'],
        ['Missouri', 'Jefferson City', 'Kansas City', 'Bluebird', 'Hawthorn'],
        ['Montana', 'Helena', 'Billings', 'Western Meadowlark', 'Bitterroot'],
        ['Nebraska', 'Lincoln', 'Omaha', 'Western Meadowlark', 'Goldenrod'],
        ['Nevada', 'Carson City', 'Las Vegas', 'Mountain Bluebird', 'Sagebrush'],
        ['New Hampshire', 'Concord', 'Manchester', 'Purple Finch', 'Purple Lilac'],
        ['New Jersey', 'Trenton', 'Newark', 'Eastern Goldfinch', 'Purple Violet'],
        ['New Mexico', 'Santa Fe', 'Albuquerque', 'Roadrunner', 'Yucca Flower'],
        ['New York', 'Albany', 'New York', 'Bluebird', 'Rose'],
        ['North Carolina', 'Raleigh', 'Charlotte', 'Cardinal', 'Dogwood'],
        ['North Dakota', 'Bismarck', 'Fargo', 'Western Meadowlark', 'Wild Prairie Rose'],
        ['Ohio', 'Columbus', 'Columbus', 'Cardinal', 'Scarlet Carnation'],
        ['Oklahoma', 'Oklahoma City', 'Oklahoma City', 'Scissor-Tailed Flycatcher', 'Mistletoe'],
        ['Oregon', 'Salem', 'Portland', 'Western Meadowlark', 'Oregon Grape'],
        ['Pennsylvania', 'Harrisburg', 'Philadelphia', 'Ruffed Grouse', 'Mountain Laurel'],
        ['Rhode Island', 'Providence', 'Providence', 'Rhode Island Red', 'Violet'],
        ['South Carolina', 'Columbia', 'Columbia', 'Carolina Wren', 'Yellow Jessamine'],
        ['South Dakota', 'Pierre', 'Sioux Falls', 'Ring-Necked Pheasant', 'American Pasqueflower'],
        ['Tennessee', 'Nashville', 'Memphis', 'Mockingbird', 'Iris'],
        ['Texas', 'Austin', 'Houston', 'Mockingbird', 'Bluebonnet'],
        ['Utah', 'Salt Lake City', 'Salt Lake City', 'California Gull', 'Sego Lily'],
        ['Vermont', 'Montpelier', 'Burlington', 'Hermit Thrush', 'Red Clover'],
        ['Virginia', 'Richmond', 'Virginia Beach', 'Cardinal', 'Dogwood'],
        ['Washington', 'Olympia', 'Seattle', 'Willow Goldfinch', 'Western Rhododendron'],
        ['West Virginia', 'Charleston', 'Charleston', 'Cardinal', 'Big Rhododendron'],
        ['Wisconsin', 'Madison', 'Milwaukee', 'Robin', 'Wood Violet'],
        ['Wyoming', 'Cheyenne', 'Cheyenne', 'Meadowlark', 'Indian Paintbrush'],
        ['Washington, D.C.', 'None', 'Washington', 'Woodthrush', 'American Beauty Rose']]

# %%
import pandas as pd
frame = pd.DataFrame(data[1:], columns=data[0])
frame = frame.set_index("State")
frame
# Out:
#                          Capital    Largest City                       Bird  \
# State
# Alabama               Montgomery      Birmingham               Yellowhammer
# Alaska                    Juneau       Anchorage           Willow Ptarmigan
# Arizona                  Phoenix         Phoenix                Cactus Wren
# Arkansas             Little Rock     Little Rock                Mockingbird
# California            Sacramento     Los Angeles    California Valley Quail
# Colorado                  Denver          Denver               Lark Bunting
# Connecticut             Hartford      Bridgeport             American Robin
# Delaware                   Dover      Wilmington           Blue Hen Chicken
# Florida              Tallahassee    Jacksonville                Mockingbird
# Georgia                  Atlanta         Atlanta             Brown Thrasher
# Hawaii                  Honolulu        Honolulu      Nene (Hawaiian Goose)
# Idaho                      Boise           Boise          Mountain Bluebird
# Illinois             Springfield         Chicago                   Cardinal
# Indiana             Indianapolis    Indianapolis                   Cardinal
# Iowa                  Des Moines      Des Moines          Eastern Goldfinch
# Kansas                    Topeka         Wichita         Western Meadowlark
# Kentucky               Frankfort      Louisville          Kentucky Cardinal
# Louisiana            Baton Rouge     New Orleans                    Pelican
# Maine                    Augusta        Portland                  Chickadee
# Maryland               Annapolis       Baltimore           Baltimore Oriole
# Massachusetts             Boston          Boston                  Chickadee
# Michigan                 Lansing         Detroit                      Robin
# Minnesota               St. Paul     Minneapolis                Common Loon
# Mississippi              Jackson         Jackson                Mockingbird
# Missouri          Jefferson City     Kansas City                   Bluebird
# Montana                   Helena        Billings         Western Meadowlark
# Nebraska                 Lincoln           Omaha         Western Meadowlark
# Nevada               Carson City       Las Vegas          Mountain Bluebird
# New Hampshire            Concord      Manchester               Purple Finch
# New Jersey               Trenton          Newark          Eastern Goldfinch
# New Mexico              Santa Fe     Albuquerque                 Roadrunner
# New York                  Albany        New York                   Bluebird
# North Carolina           Raleigh       Charlotte                   Cardinal
# North Dakota            Bismarck           Fargo         Western Meadowlark
# Ohio                    Columbus        Columbus                   Cardinal
# Oklahoma           Oklahoma City   Oklahoma City  Scissor-Tailed Flycatcher
# Oregon                     Salem        Portland         Western Meadowlark
# Pennsylvania          Harrisburg    Philadelphia              Ruffed Grouse
# Rhode Island          Providence      Providence           Rhode Island Red
# South Carolina          Columbia        Columbia              Carolina Wren
# South Dakota              Pierre     Sioux Falls       Ring-Necked Pheasant
# Tennessee              Nashville         Memphis                Mockingbird
# Texas                     Austin         Houston                Mockingbird
# Utah              Salt Lake City  Salt Lake City            California Gull
# Vermont               Montpelier      Burlington              Hermit Thrush
# Virginia                Richmond  Virginia Beach                   Cardinal
# Washington               Olympia         Seattle           Willow Goldfinch
# West Virginia         Charleston      Charleston                   Cardinal
# Wisconsin                Madison       Milwaukee                      Robin
# Wyoming                 Cheyenne        Cheyenne                 Meadowlark
# Washington, D.C.            None      Washington                 Woodthrush
#
#                                          Flower
# State
# Alabama                                Camellia
# Alaska                            Forget-me-not
# Arizona                  Saguaro Cactus Blossom
# Arkansas                          Apple Blossom
# California                         Golden Poppy
# Colorado                              Columbine
# Connecticut                     Mountain Laurel
# Delaware                          Peach Blossom
# Florida                          Orange Blossom
# Georgia                           Cherokee Rose
# Hawaii                                 Hibiscus
# Idaho                                   Syringa
# Illinois                          Native violet
# Indiana                                   Peony
# Iowa                                  Wild Rose
# Kansas                         Native Sunflower
# Kentucky                              Goldenrod
# Louisiana                              Magnolia
# Maine                White Pine Cone and Tassel
# Maryland                       Black-Eyed Susan
# Massachusetts                         Mayflower
# Michigan                          Apple Blossom
# Minnesota         Pink and White Lady's Slipper
# Mississippi                            Magnolia
# Missouri                               Hawthorn
# Montana                              Bitterroot
# Nebraska                              Goldenrod
# Nevada                                Sagebrush
# New Hampshire                      Purple Lilac
# New Jersey                        Purple Violet
# New Mexico                         Yucca Flower
# New York                                   Rose
# North Carolina                          Dogwood
# North Dakota                  Wild Prairie Rose
# Ohio                          Scarlet Carnation
# Oklahoma                              Mistletoe
# Oregon                             Oregon Grape
# Pennsylvania                    Mountain Laurel
# Rhode Island                             Violet
# South Carolina                 Yellow Jessamine
# South Dakota              American Pasqueflower
# Tennessee                                  Iris
# Texas                                Bluebonnet
# Utah                                  Sego Lily
# Vermont                              Red Clover
# Virginia                                Dogwood
# Washington                 Western Rhododendron
# West Virginia                  Big Rhododendron
# Wisconsin                           Wood Violet
# Wyoming                       Indian Paintbrush
# Washington, D.C.           American Beauty Rose

# %% [markdown]
# `2.` There are three useful calls to get information about a DataFrame.  If the identifier for your DataFrame is `df`:
# > df.info()
#
# > df.describe()
#
# > df.head()

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Alabama to Washington, D.C.
# Data columns (total 4 columns):
# Capital         51 non-null object
# Largest City    51 non-null object
# Bird            51 non-null object
# Flower          51 non-null object
# dtypes: object(4)
# memory usage: 2.0+ KB

# %%
frame.describe()
# Out:
#         Capital Largest City      Bird   Flower
# count        51           51        51       51
# unique       51           50        33       46
# top     Lansing     Portland  Cardinal  Dogwood
# freq          1            2         6        2

# %%
frame.head()
# Out:
#                 Capital Largest City                     Bird  \
# State
# Alabama      Montgomery   Birmingham             Yellowhammer
# Alaska           Juneau    Anchorage         Willow Ptarmigan
# Arizona         Phoenix      Phoenix              Cactus Wren
# Arkansas    Little Rock  Little Rock              Mockingbird
# California   Sacramento  Los Angeles  California Valley Quail
#
#                             Flower
# State
# Alabama                   Camellia
# Alaska               Forget-me-not
# Arizona     Saguaro Cactus Blossom
# Arkansas             Apple Blossom
# California            Golden Poppy

# %% [markdown]
# How many states have Cardinal as their state bird?

# %%
# From frame.describe, we see that "Cardinal" is the state bird of 6 states.

# %% [markdown]
# `3.`  What is the capital of Nebraska?

# %%
frame.loc["Nebraska", "Capital"]
# Out:
# 'Lincoln'

# %% [markdown]
# `4.` The *four corner* states are Arizona, Colorado, New Mexico and Utah, because there is a point on the earth that borders all four.  Make a dataframe, `four_corners`,  of the state birds and flowers of the four corner states.

# %%
four_corners = frame.loc[["Arizona", "Colorado", "New Mexico", "Utah"], ["Bird","Flower"]]
four_corners
# Out:
#                        Bird                  Flower
# State
# Arizona         Cactus Wren  Saguaro Cactus Blossom
# Colorado       Lark Bunting               Columbine
# New Mexico       Roadrunner            Yucca Flower
# Utah        California Gull               Sego Lily

# %% [markdown]
# `5.` Change New Mexico's flower to be Ocotillo using `four_corners.loc`.

# %%
four_corners.loc["New Mexico", "Flower"] = "Ocotillo"
four_corners
# Out:
#                        Bird                  Flower
# State
# Arizona         Cactus Wren  Saguaro Cactus Blossom
# Colorado       Lark Bunting               Columbine
# New Mexico       Roadrunner                Ocotillo
# Utah        California Gull               Sego Lily

# %% [markdown]
# `6.` Change New Mexico's flower back to "Yucca Flower" using `four_corners.iloc`.

# %%
four_corners.iloc[2, 1] = "Yucca Flower"
four_corners
# Out:
#                        Bird                  Flower
# State
# Arizona         Cactus Wren  Saguaro Cactus Blossom
# Colorado       Lark Bunting               Columbine
# New Mexico       Roadrunner            Yucca Flower
# Utah        California Gull               Sego Lily

# %% [markdown]
# `7.` Delaware's state bird has several words in its name.  What is the last word?

# %%
frame.loc["Delaware", "Bird"].split()[-1]
# Out:
# 'Chicken'

# %% [markdown]
# `8.` What are the last three characters of Oklahoma's state flower?

# %%
frame.loc["Oklahoma", "Flower"][-3:]
# Out:
# 'toe'

# %%
# 9. Here are some numbers, one number for each day of the week, with Monday being the first column, and one row 
#    for each hour of the day, the first row being the 0 hour.  Get them into a DataFrame.

numbers = [[15, 13, 11, 15, 10, 18,  3],
       [19, 12,  5, 16,  7,  3, 15],
       [15, 10,  1,  0,  9,  0,  8],
       [ 0,  7, 11, 14,  8,  5, 17],
       [ 5,  4,  9,  0, 16,  9, 15],
       [12, 13,  7, 13, 11, 12,  7],
       [ 4,  3,  1,  9, 18, 18,  6],
       [ 7,  1, 13,  0,  9,  2,  0],
       [ 8, 18,  9, 15,  5,  9, 15],
       [ 0, 14, 17,  8, 10,  7,  0],
       [12,  4,  7,  3,  0,  9, 11],
       [ 3,  8, 19,  8,  8, 19,  3],
       [13, 12,  8,  2,  4,  6, 18],
       [16, 15,  8,  4, 11, 18, 12],
       [10, 18,  3, 18,  4, 13,  8],
       [17,  4, 17,  1, 11, 12, 11],
       [ 7, 11, 14, 11,  4, 14, 18],
       [ 6, 10,  4,  9,  6, 19, 16],
       [16, 13,  0, 19, 18, 19, 17],
       [ 1, 11,  0, 12, 12,  8,  1],
       [11,  3, 14,  9,  6,  0, 19],
       [14, 14, 15, 19, 12,  9,  3],
       [14,  1,  7,  5,  1, 18, 18],
       [18,  5, 16, 18, 14,  6, 16]]

# %%
number_frame = pd.DataFrame(numbers, columns = ["Mon","Tues","Wed","Thurs","Fri","Sat","Sun"])
number_frame.index.name = "Hour"
number_frame
# Out:
#       Mon  Tues  Wed  Thurs  Fri  Sat  Sun
# Hour
# 0      15    13   11     15   10   18    3
# 1      19    12    5     16    7    3   15
# 2      15    10    1      0    9    0    8
# 3       0     7   11     14    8    5   17
# 4       5     4    9      0   16    9   15
# 5      12    13    7     13   11   12    7
# 6       4     3    1      9   18   18    6
# 7       7     1   13      0    9    2    0
# 8       8    18    9     15    5    9   15
# 9       0    14   17      8   10    7    0
# 10     12     4    7      3    0    9   11
# 11      3     8   19      8    8   19    3
# 12     13    12    8      2    4    6   18
# 13     16    15    8      4   11   18   12
# 14     10    18    3     18    4   13    8
# 15     17     4   17      1   11   12   11
# 16      7    11   14     11    4   14   18
# 17      6    10    4      9    6   19   16
# 18     16    13    0     19   18   19   17
# 19      1    11    0     12   12    8    1
# 20     11     3   14      9    6    0   19
# 21     14    14   15     19   12    9    3
# 22     14     1    7      5    1   18   18
# 23     18     5   16     18   14    6   16

# %% [markdown]
# `10.` Which day has the highest mean?  Which has the highest standard deviation?

# %%
number_frame.describe()
# Out:
#              Mon       Tues        Wed      Thurs        Fri        Sat  \
# count  24.000000  24.000000  24.000000  24.000000  24.000000  24.000000
# mean   10.125000   9.333333   9.000000   9.500000   8.916667  10.541667
# std     5.877832   5.180789   5.778521   6.480741   4.790540   6.296853
# min     0.000000   1.000000   0.000000   0.000000   0.000000   0.000000
# 25%     5.750000   4.000000   4.750000   3.750000   5.750000   6.000000
# 50%    11.500000  10.500000   8.500000   9.000000   9.000000   9.000000
# 75%    15.000000  13.000000  14.000000  15.000000  11.250000  18.000000
# max    19.000000  18.000000  19.000000  19.000000  18.000000  19.000000
#
#              Sun
# count  24.000000
# mean   10.708333
# std     6.504040
# min     0.000000
# 25%     5.250000
# 50%    11.500000
# 75%    16.250000
# max    19.000000

# %%
# Sun has the highest mean = 10.708333

# %% [markdown]
# `11.` Get the frame for the early morning hours, 5 - 7 on the weekend days

# %%
number_frame.loc[5:7,"Sat":"Sun"]
# Out:
#       Sat  Sun
# Hour
# 5      12    7
# 6      18    6
# 7       2    0

# %% [markdown]
# `12.` Make the dataframe of your `number_frame` but with pi multiplied by each number for the value.
# You'll like the `math` library for this.

# %%
import math
math.pi * number_frame
# Out:
#             Mon       Tues        Wed      Thurs        Fri        Sat  \
# Hour
# 0     47.123890  40.840704  34.557519  47.123890  31.415927  56.548668
# 1     59.690260  37.699112  15.707963  50.265482  21.991149   9.424778
# 2     47.123890  31.415927   3.141593   0.000000  28.274334   0.000000
# 3      0.000000  21.991149  34.557519  43.982297  25.132741  15.707963
# 4     15.707963  12.566371  28.274334   0.000000  50.265482  28.274334
# 5     37.699112  40.840704  21.991149  40.840704  34.557519  37.699112
# 6     12.566371   9.424778   3.141593  28.274334  56.548668  56.548668
# 7     21.991149   3.141593  40.840704   0.000000  28.274334   6.283185
# 8     25.132741  56.548668  28.274334  47.123890  15.707963  28.274334
# 9      0.000000  43.982297  53.407075  25.132741  31.415927  21.991149
# 10    37.699112  12.566371  21.991149   9.424778   0.000000  28.274334
# 11     9.424778  25.132741  59.690260  25.132741  25.132741  59.690260
# 12    40.840704  37.699112  25.132741   6.283185  12.566371  18.849556
# 13    50.265482  47.123890  25.132741  12.566371  34.557519  56.548668
# 14    31.415927  56.548668   9.424778  56.548668  12.566371  40.840704
# 15    53.407075  12.566371  53.407075   3.141593  34.557519  37.699112
# 16    21.991149  34.557519  43.982297  34.557519  12.566371  43.982297
# 17    18.849556  31.415927  12.566371  28.274334  18.849556  59.690260
# 18    50.265482  40.840704   0.000000  59.690260  56.548668  59.690260
# 19     3.141593  34.557519   0.000000  37.699112  37.699112  25.132741
# 20    34.557519   9.424778  43.982297  28.274334  18.849556   0.000000
# 21    43.982297  43.982297  47.123890  59.690260  37.699112  28.274334
# 22    43.982297   3.141593  21.991149  15.707963   3.141593  56.548668
# 23    56.548668  15.707963  50.265482  56.548668  43.982297  18.849556
#
#             Sun
# Hour
# 0      9.424778
# 1     47.123890
# 2     25.132741
# 3     53.407075
# 4     47.123890
# 5     21.991149
# 6     18.849556
# 7      0.000000
# 8     47.123890
# 9      0.000000
# 10    34.557519
# 11     9.424778
# 12    56.548668
# 13    37.699112
# 14    25.132741
# 15    34.557519
# 16    56.548668
# 17    50.265482
# 18    53.407075
# 19     3.141593
# 20    59.690260
# 21     9.424778
# 22    56.548668
# 23    50.265482

# %% [markdown]
# `13.` There are some handy functions for a DataFrame of numbers.  If the identifier for your DataFrame is `number_frame`, try:
#
# > `number_frame.sum()`
#
# What is the `type` of the object returned from the call.

# %%
the_sums = number_frame.sum()
type(the_sums), the_sums
# Out:
# (pandas.core.series.Series, Mon      243
#  Tues     224
#  Wed      216
#  Thurs    228
#  Fri      214
#  Sat      253
#  Sun      257
#  dtype: int64)

# %% [markdown]
# If the identifier for your returned object is `the_sums`, try:
#
# > `the_sums.sum()`

# %%
the_sums.sum()
# Out:
# 1635

# %% [markdown]
# `14.` If the identifier for your DataFrame is `number_frame` do:
#
# > `number_frame.(tab)`, `dir(number_frame)` or `", ".join(dir(number_frame))`  and find something else that is interesting to you.
#
# Maybe `number_frame.corr` looks interesting.  Use:
#
# > `?number_frame.corr` to discover how to use it.

# %%
number_frame.corr()
# Out:
#             Mon      Tues       Wed     Thurs       Fri       Sat       Sun
# Mon    1.000000  0.069961 -0.066564  0.097588 -0.028952 -0.014831  0.308064
# Tues   0.069961  1.000000 -0.191705  0.519273 -0.030365  0.155489 -0.132472
# Wed   -0.066564 -0.191705  1.000000 -0.076626 -0.105232 -0.133829 -0.105272
# Thurs  0.097588  0.519273 -0.076626  1.000000  0.172254  0.163543  0.031460
# Fri   -0.028952 -0.030365 -0.105232  0.172254  1.000000  0.135605 -0.264548
# Sat   -0.014831  0.155489 -0.133829  0.163543  0.135605  1.000000 -0.014022
# Sun    0.308064 -0.132472 -0.105272  0.031460 -0.264548 -0.014022  1.000000

# %% [markdown]
# `15.` You can delete a column with Python's `del` keyword.  Drop the weekend days from the data.

# %%
del number_frame["Sun"]
number_frame
# Out:
#       Mon  Tues  Wed  Thurs  Fri  Sat
# Hour
# 0      15    13   11     15   10   18
# 1      19    12    5     16    7    3
# 2      15    10    1      0    9    0
# 3       0     7   11     14    8    5
# 4       5     4    9      0   16    9
# 5      12    13    7     13   11   12
# 6       4     3    1      9   18   18
# 7       7     1   13      0    9    2
# 8       8    18    9     15    5    9
# 9       0    14   17      8   10    7
# 10     12     4    7      3    0    9
# 11      3     8   19      8    8   19
# 12     13    12    8      2    4    6
# 13     16    15    8      4   11   18
# 14     10    18    3     18    4   13
# 15     17     4   17      1   11   12
# 16      7    11   14     11    4   14
# 17      6    10    4      9    6   19
# 18     16    13    0     19   18   19
# 19      1    11    0     12   12    8
# 20     11     3   14      9    6    0
# 21     14    14   15     19   12    9
# 22     14     1    7      5    1   18
# 23     18     5   16     18   14    6

# %%
# Here's another way, and this way will drop more than one column:

number_frame.drop(["Fri", "Sat"], axis=1)
# Out:
#       Mon  Tues  Wed  Thurs
# Hour
# 0      15    13   11     15
# 1      19    12    5     16
# 2      15    10    1      0
# 3       0     7   11     14
# 4       5     4    9      0
# 5      12    13    7     13
# 6       4     3    1      9
# 7       7     1   13      0
# 8       8    18    9     15
# 9       0    14   17      8
# 10     12     4    7      3
# 11      3     8   19      8
# 12     13    12    8      2
# 13     16    15    8      4
# 14     10    18    3     18
# 15     17     4   17      1
# 16      7    11   14     11
# 17      6    10    4      9
# 18     16    13    0     19
# 19      1    11    0     12
# 20     11     3   14      9
# 21     14    14   15     19
# 22     14     1    7      5
# 23     18     5   16     18

# %% [markdown]
# `16.`  `plt.scatter(x_numbers, y_numbers)` gives a scatter plot.  Try scattering Monday's numbers against Tuesday's number.  If you make several calls to `plt.scatter` before you call `plt.show`, those several scatter plots will be in the same figure.  Maybe you can make something pretty with that.

# %%
import matplotlib.pyplot as plt
plt.scatter(number_frame["Mon"], number_frame["Tues"])
plt.scatter(number_frame["Wed"], number_frame["Thurs"])
plt.scatter(number_frame["Fri"], number_frame["Sat"])
plt.show()
