# %% [markdown]
# ## Exercises Lab01 Data Types

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# .
# ![lab_1_1_ab_solution.png](attachment:lab_1_1_ab_solution.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# .
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# .
# `1. (e)`
# ```python
# color     --->  identifier or label
#
# 33        --->  datum
#
# "color"   --->  datum
# ```

# %% [markdown]
# `2.`  Guess which method of the int gets used when the interpreter sees:
# ```python
#     3 + 4
#     ```

# %%
# __add__

# %% [markdown]
# `3.`  Try this:
# ```python
# 3/4
# ```
# What is the data type of the result?  What are the methods?
# <pre>
# </pre>

# %%
answer = 3/4
answer, type(answer), ', '.join(dir(answer))
# Out:
# (0.75,
#  float,
#  '__abs__, __add__, __bool__, __class__, __delattr__, __dir__, __divmod__, __doc__, __eq__, __float__, __floordiv__, __format__, __ge__, __getattribute__, __getformat__, __getnewargs__, __gt__, __hash__, __init__, __int__, __le__, __lt__, __mod__, __mul__, __ne__, __neg__, __new__, __pos__, __pow__, __radd__, __rdivmod__, __reduce__, __reduce_ex__, __repr__, __rfloordiv__, __rmod__, __rmul__, __round__, __rpow__, __rsub__, __rtruediv__, __setattr__, __setformat__, __sizeof__, __str__, __sub__, __subclasshook__, __truediv__, __trunc__, as_integer_ratio, conjugate, fromhex, hex, imag, is_integer, real')

# %% [markdown]
# `4.` Here's a quote from a famous song:
# <pre>
# "There will be an answer."
# </pre>
# What is its type?  Take a glimpse at its intelligence.
# <pre>
# </pre>

# %%
type("There will be an answer."), ', '.join(dir("There will be an answer."))
# Out:
# (str,
#  '__add__, __class__, __contains__, __delattr__, __dir__, __doc__, __eq__, __format__, __ge__, __getattribute__, __getitem__, __getnewargs__, __gt__, __hash__, __init__, __iter__, __le__, __len__, __lt__, __mod__, __mul__, __ne__, __new__, __reduce__, __reduce_ex__, __repr__, __rmod__, __rmul__, __setattr__, __sizeof__, __str__, __subclasshook__, capitalize, casefold, center, count, encode, endswith, expandtabs, find, format, format_map, index, isalnum, isalpha, isdecimal, isdigit, isidentifier, islower, isnumeric, isprintable, isspace, istitle, isupper, join, ljust, lower, lstrip, maketrans, partition, replace, rfind, rindex, rjust, rpartition, rsplit, rstrip, split, splitlines, startswith, strip, swapcase, title, translate, upper, zfill')

# %% [markdown]
# `5.`  Assign that quote to an identifier.  Make your identifier lower-case, meaningful, and generous.
#
# Assign "Let it be." to another identifier.
#
# What do you get when you when you <font size=3> + </font> them together?

# %%
hope = "There will be an answer."
answer = "Let it be."
hope + answer
# Out:
# 'There will be an answer.Let it be.'

# %% [markdown]
# `6.` Explore some other str methods. Skip `join`, `maketrans`, `translate`, and those with `partition` or `split` in them  -  for now.
#
# > a.  What is returned when you call any method that starts with `is`?

# %%
#  True or False -- the "booleans"

# %% [markdown]
# > b.  After you call a method on a string, the new `str` is returned.  What happened to the original `str`?  You need to assign your original `str` to an identifier to answer this question.

# %% [markdown]
# . The original `str` does not change.

# %%
original = "Chili"
all_caps = original.upper()
original, all_caps
# Out:
# ('Chili', 'CHILI')

# %% [markdown]
# > c.  Notice that `str` has an `__add__` method, so the '+' operator works on `str`s. That's what happened in `5.` above.
#
# > Also see that `__mul__` method, so you can `multiply` a `str` by an `int`.  <font size=+2>*</font> means multiply.
#
# Try:
# ```python
# 3 * "button"
# ```

# %%
3 * "button"
# Out:
# 'buttonbuttonbutton'

# %% [markdown]
# `7.` You can use your Jupyter Notebook cell as a calculator. How many Mexican pesos do you get for $141?  Find today's exchange rate online, or use the exchange rate from August 12, 2018, which was 18.91.

# %%
141 * 18.91
# Out:
# 2666.31
