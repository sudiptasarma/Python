# %% [markdown]
# # Exercises Lab17 Timed Data
# `1.` Read the `DataSets/Sacramentorealestatetransactions.csv` into a DataFrame.  Get the "sale_date" column to be a `datetime` and make it the index.

# %%
import pandas as pd
sac = pd.read_csv("DataSets/Sacramentorealestatetransactions.csv")
sac = sac.set_index("sale_date")
sac.index = pd.to_datetime(sac.index)
sac
# Out:
#                                      street             city    zip state  \
# sale_date
# 2008-05-21                     3526 HIGH ST       SACRAMENTO  95838    CA
# 2008-05-21                      51 OMAHA CT       SACRAMENTO  95823    CA
# 2008-05-21                   2796 BRANCH ST       SACRAMENTO  95815    CA
# 2008-05-21                 2805 JANETTE WAY       SACRAMENTO  95815    CA
# 2008-05-21                  6001 MCMAHON DR       SACRAMENTO  95824    CA
# 2008-05-21               5828 PEPPERMILL CT       SACRAMENTO  95841    CA
# 2008-05-21              6048 OGDEN NASH WAY       SACRAMENTO  95842    CA
# 2008-05-21                    2561 19TH AVE       SACRAMENTO  95820    CA
# 2008-05-21  11150 TRINITY RIVER DR Unit 114   RANCHO CORDOVA  95670    CA
# 2008-05-21                     7325 10TH ST        RIO LINDA  95673    CA
# 2008-05-21                 645 MORRISON AVE       SACRAMENTO  95838    CA
# ...

# %% [markdown]
# `2.` Make a dataframe of the the sales on May 15, sorted by price, with the biggest price first.

# %%
sac["2008-05-15"].sort_values("price", ascending=False).head()
# Out:
#                          street             city    zip state  beds  baths  \
# sale_date
# 2008-05-15  3882 YELLOWSTONE LN  EL DORADO HILLS  95762    CA     3      2
# 2008-05-15     8304 RED FOX WAY        ELK GROVE  95758    CA     4      2
# 2008-05-15    7933 DAFFODIL WAY   CITRUS HEIGHTS  95610    CA     3      2
# 2008-05-15      6932 RUSKUT WAY       SACRAMENTO  95823    CA     3      2
# 2008-05-15   9169 GARLINGTON CT       SACRAMENTO  95829    CA     4      3
#
#             sq__ft         type   price   latitude   longitude
# sale_date
# 2008-05-15    1362  Residential  235738  38.655245 -121.075915
# 2008-05-15    1685  Residential  235301  38.417000 -121.397424
# 2008-05-15    1216  Residential  235000  38.708824 -121.256803
# 2008-05-15    1477  Residential  234000  38.499893 -121.458890
# 2008-05-15    2280  Residential  232425  38.457679 -121.359620

# %% [markdown]
# `3.` Make a daily dataframe of the average house price each day.  If there are missing days, drop them.

# %%
sac.resample("D").mean().dropna()
# Out:
#                      zip      beds     baths       sq__ft          price  \
# sale_date
# 2008-05-15  95765.779661  2.864407  1.644068  1192.686441  167462.864407
# 2008-05-16  95748.950758  3.075758  1.890152  1366.390152  266314.886364
# 2008-05-19  95742.742537  2.574627  1.570896  1170.335821  206361.194030
# 2008-05-20  95745.463277  2.949153  1.790960  1325.045198  262797.016949
# 2008-05-21  95761.708861  3.202532  2.018987  1554.088608  245218.227848
#
#              latitude   longitude
# sale_date
# 2008-05-15  38.574386 -121.395818
# 2008-05-16  38.619988 -121.335453
# 2008-05-19  38.648755 -121.354075
# 2008-05-20  38.600978 -121.347341
# 2008-05-21  38.550141 -121.373447
